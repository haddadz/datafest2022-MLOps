# %%
# Also autoinstruments tf.keras
import mlflow.tensorflow
mlflow.tensorflow.autolog()

# %%
import mlflow
mlflow.log_metric("accuracy", 0.9)

# %%
import mlflow
mlflow.log_param("learning_rate", 0.001)

# %%
import mlflow.sklearn
mlflow.sklearn.log_model(model, "myModel")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <command-2541115443740009> in <cell line: 2>()
#       1 import mlflow.sklearn
# ----> 2 mlflow.sklearn.log_model(model, "myModel")
#
# NameError: name 'model' is not defined

# %%
import mlflow
mlflow.log_artifact("/tmp/my-file", "myArtifactPath")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /databricks/python/lib/python3.9/site-packages/mlflow/store/artifact/databricks_artifact_repo.py in _signed_url_upload_file(self, credentials, local_file)
#     238             # Putting an empty file in a request by reading file bytes gives 501 error.
# --> 239             if os.stat(local_file).st_size == 0:
#     240                 with rest_utils.cloud_storage_http_request(
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/my-file'
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# <command-2541115443740010> in <cell line: 2>()
#       1 import mlflow
# ----> 2 mlflow.log_artifact("/tmp/my-file", "myArtifactPath")
#
# /databricks/python/lib/python3.9/site-packages/mlflow/tracking/fluent.py in log_artifact(local_path, artifact_path)
#     750     """
#     751     run_id = _get_or_start_run().info.run_id
# --> 752     MlflowClient().log_artifact(run_id, local_path, artifact_path)
#     753
#     754
#
# /databricks/python/lib/python3.9/site-packages/mlflow/tracking/client.py in log_artifact(self, run_id, local_path, artifact_path)
#     953             is_dir: False
#     954         """
# --> 955         self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#     956
#     957     def log_artifacts(
#
# /databricks/python/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py in log_artifact(self, run_id, local_path, artifact_path)
#     363             artifact_repo.log_artifacts(local_path, path_name)
#     364         else:
# --> 365             artifact_repo.log_artifact(local_path, artifact_path)
#     366
#     367     def log_artifacts(self, run_id, local_dir, artifact_path=None):
#
# /databricks/python/lib/python3.9/site-packages/mlflow/store/artifact/databricks_artifact_repo.py in log_artifact(self, local_file, artifact_path)
#     325             run_id=self.run_id, paths=[run_relative_artifact_path]
#     326         )[0]
# --> 327         self._upload_to_cloud(
#     328             cloud_credential_info=write_credential_info,
#     329             src_file_path=local_file,
#
# /databricks/python/lib/python3.9/site-packages/mlflow/store/artifact/databricks_artifact_repo.py in _upload_to_cloud(self, cloud_credential_info, src_file_path, dst_run_relative_artifact_path)
#     266             ArtifactCredentialType.GCP_SIGNED_URL,
#     267         ]:
# --> 268             self._signed_url_upload_file(cloud_credential_info, src_file_path)
#     269         else:
#     270             raise MlflowException(
#
# /databricks/python/lib/python3.9/site-packages/mlflow/store/artifact/databricks_artifact_repo.py in _signed_url_upload_file(self, credentials, local_file)
#     249                         augmented_raise_for_status(response)
#     250         except Exception as err:
# --> 251             raise MlflowException(err)
#     252
#     253     def _upload_to_cloud(
#
# MlflowException: [Errno 2] No such file or directory: '/tmp/my-file'
